# %%
import numpy as np
import random

import sys
sys.path.append("..")

from code.rd import ReactionDiffusionModel

import matplotlib.pyplot as plt
import matplotlib.animation
matplotlib.rcParams['animation.embed_limit'] = 2*128

from IPython.display import HTML
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 7
#       4 import sys
#       5 sys.path.append("..")
# ----> 7 from code.rd import ReactionDiffusionModel
#       9 import matplotlib.pyplot as plt
#      10 import matplotlib.animation
#
# ModuleNotFoundError: No module named 'code.rd'; 'code' is not a package
