# %% [markdown]
# # Gray–Scott reaction–diffusion system

# %% [markdown]
# ### How do variations in the feed and kill rates of a 2D Gray–Scott reaction–diffusion system influence the emergence, stability, and transitions between distinct spatial pattern regimes?

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
N = 100
DX = 1.0
DT = 1.0

D_U = 0.16
D_V = 0.08

N_STEPS = 5000

F_VALUES = np.linspace(0.02, 0.08, 10)
K_VALUES = np.linspace(0.04, 0.07, 10)

# %%
def initialize_grid():
    U = np.ones((N, N))
    V = np.zeros((N, N))

    r = 10
    center = N // 2
    U[center-r:center+r, center-r:center+r] = 0.5
    V[center-r:center+r, center-r:center+r] = 0.25

    return U, V

# %%
def laplacian(X):
    return (
        np.roll(X,  1, axis=0) +
        np.roll(X, -1, axis=0) +
        np.roll(X,  1, axis=1) +
        np.roll(X, -1, axis=1) -
        4 * X
    )

# %%
def update(U, V, F, k):
    Lu = laplacian(U)
    Lv = laplacian(V)

    reaction = U * V**2

    U_new = U + DT * (D_U * Lu - reaction + F * (1 - U))
    V_new = V + DT * (D_V * Lv + reaction - (F + k) * V)

    return U_new, V_new

# %%
def run_simulation(F, k):
    U, V = initialize_grid()

    for _ in range(N_STEPS):
        U, V = update(U, V, F, k)

    return V

# %%
def spatial_variance(V):
    return np.var(V)

# %%
pattern_map = np.zeros((len(F_VALUES), len(K_VALUES)))

for i, F in enumerate(F_VALUES):
    for j, k in enumerate(K_VALUES):
        V_final = run_simulation(F, k)
        pattern_map[i, j] = spatial_variance(V_final)

# %%
plt.figure(figsize=(6, 5))
plt.imshow(
    pattern_map,
    origin="lower",
    extent=[K_VALUES[0], K_VALUES[-1], F_VALUES[0], F_VALUES[-1]],
    aspect="auto"
)
plt.colorbar(label="Variance of V")
plt.xlabel("k (kill rate)")
plt.ylabel("F (feed rate)")
plt.title("Pattern map in (F, k) space")
plt.show()

# %%
examples = [
    (0.03, 0.062),
    (0.04, 0.06),
    (0.05, 0.055)
]

plt.figure(figsize=(12, 4))

for i, (F, k) in enumerate(examples):
    V = run_simulation(F, k)
    plt.subplot(1, 3, i+1)
    plt.imshow(V, cmap="inferno")
    plt.title(f"F={F}, k={k}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
def print_grid(Z, Du, Dv, F, k):
    plt.figure(figsize=(12, 4))

    plt.imshow(Z, cmap="inferno")
    plt.title(f"Du={Du:.2f}, Dv={Dv:.2f}, F={F:.2f}, k={k:.2f}")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
F_VALUES = np.linspace(0.02, 0.08, 10)
K_VALUES = np.linspace(0.04, 0.07, 10)

for f in F_VALUES:
    b = run_simulation(f, k)
        
    print_grid(b, D_U, D_V, f, k)

# %%
for k in K_VALUES:
    b = run_simulation(f, k)
        
    print_grid(b, D_U, D_V, F, k)

# %%
def update(U, V, F, k, Du, Dv):
    Lu = laplacian(U)
    Lv = laplacian(V)

    reaction = U * V**2

    U_new = U + DT * (Du * Lu - reaction + F * (1 - U))
    V_new = V + DT * (Dv * Lv + reaction - (F + k) * V)

    return U_new, V_new

# %%
def run_simulation(F, k, du, dv):
    U, V = initialize_grid()

    for _ in range(N_STEPS):
        U, V = update(U, V, F, k, du, dv)

    return V

# %%
F = 0.05
k = 0.06

D_VALUES = np.linspace(0.1, 0.5, 10)

for d in D_VALUES:
    b = run_simulation(F, k, d, D_V)
    print_grid(b, d, D_V, F, k)
# Out:
# /tmp/ipykernel_18259/495051654.py:3: RuntimeWarning: overflow encountered in subtract
#   np.roll(X,  1, axis=0) +
# /tmp/ipykernel_18259/2615696340.py:5: RuntimeWarning: invalid value encountered in multiply
#   reaction = U * V**2
# /tmp/ipykernel_18259/495051654.py:3: RuntimeWarning: invalid value encountered in add
#   np.roll(X,  1, axis=0) +
# /tmp/ipykernel_18259/2615696340.py:5: RuntimeWarning: overflow encountered in square
#   reaction = U * V**2
# /tmp/ipykernel_18259/2615696340.py:5: RuntimeWarning: overflow encountered in multiply
#   reaction = U * V**2
# /tmp/ipykernel_18259/2615696340.py:7: RuntimeWarning: invalid value encountered in add
#   U_new = U + DT * (Du * Lu - reaction + F * (1 - U))
# /tmp/ipykernel_18259/2615696340.py:8: RuntimeWarning: invalid value encountered in add
#   V_new = V + DT * (Dv * Lv + reaction - (F + k) * V)
# /tmp/ipykernel_18259/495051654.py:7: RuntimeWarning: overflow encountered in multiply
#   4 * X

# %%
F = 0.05
k = 0.06

D_VALUES = np.linspace(0.1, 0.9, 10)

for d in D_VALUES:
    b = run_simulation(F, k, D_U, d)
    print_grid(b, D_U, d, F, k)
